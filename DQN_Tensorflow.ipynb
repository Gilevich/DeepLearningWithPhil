# %% [markdown]
# <a href="https://colab.research.google.com/github/Gilevich/DeepLearningWithPhil/blob/master/DQN_Tensorflow.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random
import numpy as np
import gym
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.models import load_model

# %%
class ReplayBuffer():
  def __init__(self, max_size, input_dims):
    self.mem_size = max_size
    self.mem_cntr = 0

    self.state_memory = np.zeros((self.mem_size, *input_dims), dtype=np.float32)
    self.new_state_memory = np.zeros((self.mem_size, *input_dims), dtype=np.float32)
    self.action_memory = np.zeros(self.mem_size, dtype=np.int32)
    self.reward_memory = np.zeros(self.mem_size, dtype=np.float32)
    self.terminal_memory = np.zeros(self.mem_size, dtype=np.float32)

  def store_transition(self, state, action, reward, state_, done):
    index = self.mem_cntr % self.mem_size
    self.state_memory[index] = state 
    self.new_state_memory[index] = state_
    self.reward_memory[index] = reward
    self.action_memory[index] = action
    self.terminal_memory[index] = 1 - int(done)
    self.mem_cntr += 1

  def sample_buffer(self, batch_size):
    max_mem = min(self.mem_cntr, self.mem_size)
    batch = np.random.choice(max_mem, batch_size, replace = False)

    states = self.state_memory[batch]
    states_ = self.new_state_memory[batch]
    rewards = self.reward_memory[batch]
    actions = self.action_memory[batch]
    terminal = self.terminal_memory[batch]

    return states, actions, rewards, states_, terminal

# %%
def build_dqn(lr, n_actions, input_dims, fc1_dims, fc2_dims):
  model = keras.Sequential([keras.layers.Dense(fc1_dims, activation='relu'),
                            keras.layers.Dense(fc2_dims, activation='relu'),
                            keras.layers.Dense(n_actions, activation=None)])
  model.compile(optimizer=Adam(learning_rate=lr), loss='mean_squared_error')

  return model

# %%
class Agent():
  def __init__(self, lr, gamma, n_actions, epsilon, batch_size, input_dims, 
               epsilon_dec=1e-3, epsilon_end=0.01, mem_size=1000000, fname='dqn_model.h5'):
    self.action_space = [i for i in range(n_actions)]
    self.gamma = gamma
    self.epsilon = epsilon
    self.eps_dec = epsilon_dec
    self.eps_min = epsilon_end
    self.batch_size = batch_size
    self.model_file = fname
    self.memory = ReplayBuffer(mem_size, input_dims)
    self.q_eval = build_dqn(lr, n_actions, input_dims, 256, 256)

  def store_transition(self, state, action, reward, new_state, done):
    self.memory.store_transition(state, action, reward, new_state, done)

  def choise_action(self, observation):
    if np.random.random() < self.epsilon:
      action = np.random.choice(self.action_space)
    else:
      state = np.array([observation])
      actions = self.q_eval.predict(state)

      action = np.argmax(actions)

    return action

  def learn(self):
    if self.memory.mem_cntr < self.batch_size:
      return
    
    states, actions, rewards, states_, dones = \
          self.memory.sample_buffer(self.batch_size)

    q_eval = self.q_eval.predict(states)
    q_next = self.q_eval.predict(states_)

    q_target = np.copy(q_eval)
    batch_index = np.arange(self.batch_size, dtype=np.int32)

    q_target[batch_index, actions] = rewards + self.gamma * np.max(q_next, axis=1)*dones
  

    self.q_eval.train_on_batch(states, q_target)

    self.epsilon = self.epsilon = self.epsilon - self.eps_dec if self.epsilon > \
                  self.eps_min else self.eps_min

  def save_model(self):
    self.q_eval.save(self.model_file)

  def load_model(self):
    self.q_eval = load_model(self.model_file)

# %%
def main():
  tf.compat.v1.disable_eager_execution()
  env = gym.make("CartPole-v0")
  lr = 0.001
  n_games = 500
  agent = Agent(gamma=0.99, epsilon=1.0, lr=lr,
                input_dims=env.observation_space.shape,
                n_actions=env.action_space.n, mem_size=1000000, batch_size=64,
                epsilon_end=0.01)
  scores = []
  eps_history = []

  for i in range(n_games):
    done = Falsescore = 0
    score = 0
    observation = env.reset()
    while not done:
      action = agent.choise_action(observation)
      observation_, reward, done, info = env.step(action)
      score += reward
      agent.store_transition(observation, action, reward, observation_, done)
      observation = observation_
      agent.learn()
    eps_history.append(agent.epsilon)
    scores.append(score)

    avg_score = np.mean(scores[-100:])
    print('episode: ', i, 'score %.2f' % score, 
          'average_score %.2f' % avg_score,
          'epsilon %.2f' % agent.epsilon)
    filename = 'lunarlander_tf2.png'
    x = [i+1 for i in range(n_games)]

# %%
main()
# Out:
# episode:  0 score 10.00 average_score 10.00 epsilon 1.00
# episode:  1 score 21.00 average_score 15.50 epsilon 1.00
# episode:  2 score 9.00 average_score 13.33 epsilon 1.00
# episode:  3 score 19.00 average_score 14.75 epsilon 1.00
# episode:  4 score 15.00 average_score 14.80 epsilon 0.99
# episode:  5 score 20.00 average_score 15.67 epsilon 0.97
# episode:  6 score 25.00 average_score 17.00 epsilon 0.94
# episode:  7 score 23.00 average_score 17.75 epsilon 0.92
# episode:  8 score 16.00 average_score 17.56 epsilon 0.90
# episode:  9 score 17.00 average_score 17.50 epsilon 0.89
# episode:  10 score 16.00 average_score 17.36 epsilon 0.87
# episode:  11 score 30.00 average_score 18.42 epsilon 0.84
# episode:  12 score 10.00 average_score 17.77 epsilon 0.83
# episode:  13 score 13.00 average_score 17.43 epsilon 0.82
# episode:  14 score 13.00 average_score 17.13 epsilon 0.81
# episode:  15 score 19.00 average_score 17.25 epsilon 0.79
# episode:  16 score 40.00 average_score 18.59 epsilon 0.75
# episode:  17 score 13.00 average_score 18.28 epsilon 0.73
# episode:  18 score 14.00 average_score 18.05 epsilon 0.72
# episode:  19 score 14.00 average_score 17.85 epsilon 0.71
# episode:  20 score 18.00 average_score 17.86 epsilon 0.69
# episode:  21 score 13.00 average_score 17.64 epsilon 0.67
# episode:  22 score 14.00 average_score 17.48 epsilon 0.66
# episode:  23 score 24.00 average_score 17.75 epsilon 0.64
# episode:  24 score 15.00 average_score 17.64 epsilon 0.62
# episode:  25 score 11.00 average_score 17.38 epsilon 0.61
# episode:  26 score 14.00 average_score 17.26 epsilon 0.60
# episode:  27 score 15.00 average_score 17.18 epsilon 0.58
# episode:  28 score 25.00 average_score 17.45 epsilon 0.56
# episode:  29 score 10.00 average_score 17.20 epsilon 0.55
# episode:  30 score 13.00 average_score 17.06 epsilon 0.53
# episode:  31 score 9.00 average_score 16.81 epsilon 0.52
# episode:  32 score 13.00 average_score 16.70 epsilon 0.51
# episode:  33 score 10.00 average_score 16.50 epsilon 0.50
# episode:  34 score 28.00 average_score 16.83 epsilon 0.47
# episode:  35 score 21.00 average_score 16.94 epsilon 0.45
# episode:  36 score 13.00 average_score 16.84 epsilon 0.44
# episode:  37 score 15.00 average_score 16.79 epsilon 0.42
# episode:  38 score 36.00 average_score 17.28 epsilon 0.39
# episode:  39 score 19.00 average_score 17.32 epsilon 0.37
# episode:  40 score 45.00 average_score 18.00 epsilon 0.32
# episode:  41 score 21.00 average_score 18.07 epsilon 0.30
# episode:  42 score 21.00 average_score 18.14 epsilon 0.28
# episode:  43 score 49.00 average_score 18.84 epsilon 0.23
# episode:  44 score 110.00 average_score 20.87 epsilon 0.12
# episode:  45 score 74.00 average_score 22.02 epsilon 0.05
# episode:  46 score 40.00 average_score 22.40 epsilon 0.01
# episode:  47 score 32.00 average_score 22.60 epsilon 0.01
# episode:  48 score 53.00 average_score 23.22 epsilon 0.01
# episode:  49 score 54.00 average_score 23.84 epsilon 0.01
# episode:  50 score 81.00 average_score 24.96 epsilon 0.01
# episode:  51 score 109.00 average_score 26.58 epsilon 0.01
# episode:  52 score 71.00 average_score 27.42 epsilon 0.01
# episode:  53 score 106.00 average_score 28.87 epsilon 0.01
# episode:  54 score 52.00 average_score 29.29 epsilon 0.01
# episode:  55 score 80.00 average_score 30.20 epsilon 0.01
# episode:  56 score 72.00 average_score 30.93 epsilon 0.01
# episode:  57 score 88.00 average_score 31.91 epsilon 0.01
# episode:  58 score 66.00 average_score 32.49 epsilon 0.01
# episode:  59 score 118.00 average_score 33.92 epsilon 0.01
# episode:  60 score 84.00 average_score 34.74 epsilon 0.01
# episode:  61 score 187.00 average_score 37.19 epsilon 0.01
# episode:  62 score 120.00 average_score 38.51 epsilon 0.01
# episode:  63 score 101.00 average_score 39.48 epsilon 0.01
# episode:  64 score 143.00 average_score 41.08 epsilon 0.01
# episode:  65 score 85.00 average_score 41.74 epsilon 0.01
# episode:  66 score 117.00 average_score 42.87 epsilon 0.01
# episode:  67 score 124.00 average_score 44.06 epsilon 0.01
# episode:  68 score 108.00 average_score 44.99 epsilon 0.01
# episode:  69 score 200.00 average_score 47.20 epsilon 0.01
# episode:  70 score 133.00 average_score 48.41 epsilon 0.01
# episode:  71 score 200.00 average_score 50.51 epsilon 0.01
# episode:  72 score 200.00 average_score 52.56 epsilon 0.01
# episode:  73 score 132.00 average_score 53.64 epsilon 0.01
# episode:  74 score 200.00 average_score 55.59 epsilon 0.01
# episode:  75 score 200.00 average_score 57.49 epsilon 0.01
# episode:  76 score 200.00 average_score 59.34 epsilon 0.01
# episode:  77 score 200.00 average_score 61.14 epsilon 0.01
# episode:  78 score 200.00 average_score 62.90 epsilon 0.01
# episode:  79 score 200.00 average_score 64.61 epsilon 0.01
# episode:  80 score 200.00 average_score 66.28 epsilon 0.01
# episode:  81 score 200.00 average_score 67.91 epsilon 0.01
# episode:  82 score 200.00 average_score 69.51 epsilon 0.01
# episode:  83 score 200.00 average_score 71.06 epsilon 0.01
# episode:  84 score 200.00 average_score 72.58 epsilon 0.01
# episode:  85 score 200.00 average_score 74.06 epsilon 0.01
# episode:  86 score 200.00 average_score 75.51 epsilon 0.01
# episode:  87 score 200.00 average_score 76.92 epsilon 0.01
# episode:  88 score 200.00 average_score 78.30 epsilon 0.01
# episode:  89 score 200.00 average_score 79.66 epsilon 0.01
# episode:  90 score 200.00 average_score 80.98 epsilon 0.01
# episode:  91 score 200.00 average_score 82.27 epsilon 0.01
# episode:  92 score 200.00 average_score 83.54 epsilon 0.01
# episode:  93 score 200.00 average_score 84.78 epsilon 0.01
# episode:  94 score 200.00 average_score 85.99 epsilon 0.01
# episode:  95 score 200.00 average_score 87.18 epsilon 0.01
# episode:  96 score 200.00 average_score 88.34 epsilon 0.01
# episode:  97 score 200.00 average_score 89.48 epsilon 0.01
# episode:  98 score 200.00 average_score 90.60 epsilon 0.01
# episode:  99 score 200.00 average_score 91.69 epsilon 0.01
# episode:  100 score 200.00 average_score 93.59 epsilon 0.01
# episode:  101 score 200.00 average_score 95.38 epsilon 0.01
# episode:  102 score 200.00 average_score 97.29 epsilon 0.01
# episode:  103 score 200.00 average_score 99.10 epsilon 0.01
# episode:  104 score 200.00 average_score 100.95 epsilon 0.01
# episode:  105 score 200.00 average_score 102.75 epsilon 0.01
# episode:  106 score 200.00 average_score 104.50 epsilon 0.01
# episode:  107 score 200.00 average_score 106.27 epsilon 0.01
# episode:  108 score 200.00 average_score 108.11 epsilon 0.01
# episode:  109 score 200.00 average_score 109.94 epsilon 0.01
# episode:  110 score 200.00 average_score 111.78 epsilon 0.01
# episode:  111 score 200.00 average_score 113.48 epsilon 0.01
# episode:  112 score 200.00 average_score 115.38 epsilon 0.01
# episode:  113 score 200.00 average_score 117.25 epsilon 0.01
# episode:  114 score 200.00 average_score 119.12 epsilon 0.01
# episode:  115 score 200.00 average_score 120.93 epsilon 0.01
# episode:  116 score 200.00 average_score 122.53 epsilon 0.01
# episode:  117 score 200.00 average_score 124.40 epsilon 0.01
# episode:  118 score 200.00 average_score 126.26 epsilon 0.01
# episode:  119 score 200.00 average_score 128.12 epsilon 0.01
# episode:  120 score 200.00 average_score 129.94 epsilon 0.01
# episode:  121 score 200.00 average_score 131.81 epsilon 0.01
# episode:  122 score 200.00 average_score 133.67 epsilon 0.01
# episode:  123 score 200.00 average_score 135.43 epsilon 0.01
# episode:  124 score 200.00 average_score 137.28 epsilon 0.01
# episode:  125 score 200.00 average_score 139.17 epsilon 0.01
# episode:  126 score 200.00 average_score 141.03 epsilon 0.01
# episode:  127 score 200.00 average_score 142.88 epsilon 0.01
# episode:  128 score 200.00 average_score 144.63 epsilon 0.01
# episode:  129 score 200.00 average_score 146.53 epsilon 0.01
# episode:  130 score 200.00 average_score 148.40 epsilon 0.01
# episode:  131 score 200.00 average_score 150.31 epsilon 0.01
# episode:  132 score 200.00 average_score 152.18 epsilon 0.01
# episode:  133 score 200.00 average_score 154.08 epsilon 0.01
# episode:  134 score 200.00 average_score 155.80 epsilon 0.01
# episode:  135 score 200.00 average_score 157.59 epsilon 0.01
# episode:  136 score 200.00 average_score 159.46 epsilon 0.01
# episode:  137 score 200.00 average_score 161.31 epsilon 0.01
# episode:  138 score 200.00 average_score 162.95 epsilon 0.01
# episode:  139 score 200.00 average_score 164.76 epsilon 0.01
# episode:  140 score 200.00 average_score 166.31 epsilon 0.01
# episode:  141 score 200.00 average_score 168.10 epsilon 0.01
# episode:  142 score 200.00 average_score 169.89 epsilon 0.01
# episode:  143 score 200.00 average_score 171.40 epsilon 0.01
# episode:  144 score 200.00 average_score 172.30 epsilon 0.01
# episode:  145 score 200.00 average_score 173.56 epsilon 0.01
# episode:  146 score 200.00 average_score 175.16 epsilon 0.01
# episode:  147 score 200.00 average_score 176.84 epsilon 0.01
# episode:  148 score 200.00 average_score 178.31 epsilon 0.01
# episode:  149 score 200.00 average_score 179.77 epsilon 0.01
# episode:  150 score 200.00 average_score 180.96 epsilon 0.01
# episode:  151 score 200.00 average_score 181.87 epsilon 0.01
# episode:  152 score 200.00 average_score 183.16 epsilon 0.01
# episode:  153 score 200.00 average_score 184.10 epsilon 0.01
# episode:  154 score 200.00 average_score 185.58 epsilon 0.01
# episode:  155 score 200.00 average_score 186.78 epsilon 0.01
# episode:  156 score 200.00 average_score 188.06 epsilon 0.01
# episode:  157 score 171.00 average_score 188.89 epsilon 0.01
# episode:  158 score 9.00 average_score 188.32 epsilon 0.01
# episode:  159 score 9.00 average_score 187.23 epsilon 0.01
# episode:  160 score 10.00 average_score 186.49 epsilon 0.01
# episode:  161 score 10.00 average_score 184.72 epsilon 0.01
# episode:  162 score 9.00 average_score 183.61 epsilon 0.01
# episode:  163 score 9.00 average_score 182.69 epsilon 0.01
# episode:  164 score 200.00 average_score 183.26 epsilon 0.01
# episode:  165 score 200.00 average_score 184.41 epsilon 0.01
# episode:  166 score 200.00 average_score 185.24 epsilon 0.01
# episode:  167 score 200.00 average_score 186.00 epsilon 0.01
# episode:  168 score 200.00 average_score 186.92 epsilon 0.01
# episode:  169 score 200.00 average_score 186.92 epsilon 0.01
# episode:  170 score 200.00 average_score 187.59 epsilon 0.01
# episode:  171 score 200.00 average_score 187.59 epsilon 0.01
# episode:  172 score 200.00 average_score 187.59 epsilon 0.01
# episode:  173 score 200.00 average_score 188.27 epsilon 0.01
# episode:  174 score 200.00 average_score 188.27 epsilon 0.01
# episode:  175 score 200.00 average_score 188.27 epsilon 0.01
# episode:  176 score 200.00 average_score 188.27 epsilon 0.01
# episode:  177 score 200.00 average_score 188.27 epsilon 0.01
# episode:  178 score 200.00 average_score 188.27 epsilon 0.01
# episode:  179 score 200.00 average_score 188.27 epsilon 0.01
# episode:  180 score 200.00 average_score 188.27 epsilon 0.01
# episode:  181 score 200.00 average_score 188.27 epsilon 0.01
# episode:  182 score 200.00 average_score 188.27 epsilon 0.01
# episode:  183 score 200.00 average_score 188.27 epsilon 0.01
# episode:  184 score 200.00 average_score 188.27 epsilon 0.01
# episode:  185 score 200.00 average_score 188.27 epsilon 0.01
# episode:  186 score 200.00 average_score 188.27 epsilon 0.01
# episode:  187 score 200.00 average_score 188.27 epsilon 0.01
# episode:  188 score 200.00 average_score 188.27 epsilon 0.01
# episode:  189 score 200.00 average_score 188.27 epsilon 0.01
# episode:  190 score 200.00 average_score 188.27 epsilon 0.01
# episode:  191 score 200.00 average_score 188.27 epsilon 0.01
# episode:  192 score 200.00 average_score 188.27 epsilon 0.01
# episode:  193 score 200.00 average_score 188.27 epsilon 0.01
# episode:  194 score 197.00 average_score 188.24 epsilon 0.01
# episode:  195 score 200.00 average_score 188.24 epsilon 0.01
# episode:  196 score 200.00 average_score 188.24 epsilon 0.01
# episode:  197 score 200.00 average_score 188.24 epsilon 0.01
# episode:  198 score 169.00 average_score 187.93 epsilon 0.01
# episode:  199 score 155.00 average_score 187.48 epsilon 0.01
# episode:  200 score 200.00 average_score 187.48 epsilon 0.01
# episode:  201 score 200.00 average_score 187.48 epsilon 0.01
# episode:  202 score 159.00 average_score 187.07 epsilon 0.01
# episode:  203 score 200.00 average_score 187.07 epsilon 0.01
# episode:  204 score 171.00 average_score 186.78 epsilon 0.01
# episode:  205 score 172.00 average_score 186.50 epsilon 0.01
# episode:  206 score 200.00 average_score 186.50 epsilon 0.01
# episode:  207 score 200.00 average_score 186.50 epsilon 0.01
# episode:  208 score 200.00 average_score 186.50 epsilon 0.01
# episode:  209 score 171.00 average_score 186.21 epsilon 0.01
# episode:  210 score 187.00 average_score 186.08 epsilon 0.01
# episode:  211 score 160.00 average_score 185.68 epsilon 0.01
# episode:  212 score 171.00 average_score 185.39 epsilon 0.01
# episode:  213 score 200.00 average_score 185.39 epsilon 0.01
# episode:  214 score 183.00 average_score 185.22 epsilon 0.01
# episode:  215 score 161.00 average_score 184.83 epsilon 0.01
# episode:  216 score 200.00 average_score 184.83 epsilon 0.01
# episode:  217 score 200.00 average_score 184.83 epsilon 0.01
# episode:  218 score 200.00 average_score 184.83 epsilon 0.01
# episode:  219 score 200.00 average_score 184.83 epsilon 0.01
# episode:  220 score 200.00 average_score 184.83 epsilon 0.01
# episode:  221 score 200.00 average_score 184.83 epsilon 0.01
# episode:  222 score 200.00 average_score 184.83 epsilon 0.01
# episode:  223 score 200.00 average_score 184.83 epsilon 0.01
# episode:  224 score 199.00 average_score 184.82 epsilon 0.01
# episode:  225 score 200.00 average_score 184.82 epsilon 0.01
# episode:  226 score 200.00 average_score 184.82 epsilon 0.01
# episode:  227 score 200.00 average_score 184.82 epsilon 0.01
# episode:  228 score 169.00 average_score 184.51 epsilon 0.01
# episode:  229 score 200.00 average_score 184.51 epsilon 0.01
# episode:  230 score 200.00 average_score 184.51 epsilon 0.01
# episode:  231 score 200.00 average_score 184.51 epsilon 0.01
# episode:  232 score 200.00 average_score 184.51 epsilon 0.01
# episode:  233 score 170.00 average_score 184.21 epsilon 0.01
# episode:  234 score 128.00 average_score 183.49 epsilon 0.01
# episode:  235 score 173.00 average_score 183.22 epsilon 0.01
# episode:  236 score 144.00 average_score 182.66 epsilon 0.01
# episode:  237 score 147.00 average_score 182.13 epsilon 0.01
# episode:  238 score 124.00 average_score 181.37 epsilon 0.01
# episode:  239 score 127.00 average_score 180.64 epsilon 0.01
# episode:  240 score 167.00 average_score 180.31 epsilon 0.01
# episode:  241 score 144.00 average_score 179.75 epsilon 0.01
# episode:  242 score 156.00 average_score 179.31 epsilon 0.01
# episode:  243 score 168.00 average_score 178.99 epsilon 0.01
# episode:  244 score 200.00 average_score 178.99 epsilon 0.01
# episode:  245 score 169.00 average_score 178.68 epsilon 0.01
# episode:  246 score 200.00 average_score 178.68 epsilon 0.01
# episode:  247 score 108.00 average_score 177.76 epsilon 0.01
# episode:  248 score 198.00 average_score 177.74 epsilon 0.01
# episode:  249 score 127.00 average_score 177.01 epsilon 0.01
# episode:  250 score 143.00 average_score 176.44 epsilon 0.01
# episode:  251 score 200.00 average_score 176.44 epsilon 0.01
# episode:  252 score 200.00 average_score 176.44 epsilon 0.01
# episode:  253 score 200.00 average_score 176.44 epsilon 0.01
# episode:  254 score 133.00 average_score 175.77 epsilon 0.01
# episode:  255 score 120.00 average_score 174.97 epsilon 0.01
# episode:  256 score 153.00 average_score 174.50 epsilon 0.01
# episode:  257 score 200.00 average_score 174.79 epsilon 0.01
# episode:  258 score 200.00 average_score 176.70 epsilon 0.01
# episode:  259 score 200.00 average_score 178.61 epsilon 0.01
# episode:  260 score 140.00 average_score 179.91 epsilon 0.01
# episode:  261 score 200.00 average_score 181.81 epsilon 0.01
# episode:  262 score 200.00 average_score 183.72 epsilon 0.01
# episode:  263 score 111.00 average_score 184.74 epsilon 0.01
# episode:  264 score 81.00 average_score 183.55 epsilon 0.01
# episode:  265 score 200.00 average_score 183.55 epsilon 0.01
# episode:  266 score 200.00 average_score 183.55 epsilon 0.01
# episode:  267 score 200.00 average_score 183.55 epsilon 0.01
# episode:  268 score 200.00 average_score 183.55 epsilon 0.01
# episode:  269 score 200.00 average_score 183.55 epsilon 0.01
# episode:  270 score 181.00 average_score 183.36 epsilon 0.01
# episode:  271 score 127.00 average_score 182.63 epsilon 0.01
# episode:  272 score 149.00 average_score 182.12 epsilon 0.01
# episode:  273 score 200.00 average_score 182.12 epsilon 0.01
# episode:  274 score 190.00 average_score 182.02 epsilon 0.01
# episode:  275 score 123.00 average_score 181.25 epsilon 0.01
# episode:  276 score 147.00 average_score 180.72 epsilon 0.01
# episode:  277 score 194.00 average_score 180.66 epsilon 0.01
# episode:  278 score 200.00 average_score 180.66 epsilon 0.01
# episode:  279 score 200.00 average_score 180.66 epsilon 0.01
# episode:  280 score 200.00 average_score 180.66 epsilon 0.01
# episode:  281 score 138.00 average_score 180.04 epsilon 0.01
# episode:  282 score 200.00 average_score 180.04 epsilon 0.01
# episode:  283 score 200.00 average_score 180.04 epsilon 0.01
# episode:  284 score 200.00 average_score 180.04 epsilon 0.01
# episode:  285 score 200.00 average_score 180.04 epsilon 0.01
# episode:  286 score 200.00 average_score 180.04 epsilon 0.01
# episode:  287 score 200.00 average_score 180.04 epsilon 0.01
# episode:  288 score 200.00 average_score 180.04 epsilon 0.01
# episode:  289 score 200.00 average_score 180.04 epsilon 0.01
# episode:  290 score 200.00 average_score 180.04 epsilon 0.01
# episode:  291 score 200.00 average_score 180.04 epsilon 0.01
# episode:  292 score 200.00 average_score 180.04 epsilon 0.01
# episode:  293 score 200.00 average_score 180.04 epsilon 0.01
# episode:  294 score 200.00 average_score 180.07 epsilon 0.01
# episode:  295 score 200.00 average_score 180.07 epsilon 0.01
# episode:  296 score 165.00 average_score 179.72 epsilon 0.01
# episode:  297 score 200.00 average_score 179.72 epsilon 0.01
# episode:  298 score 109.00 average_score 179.12 epsilon 0.01
# episode:  299 score 200.00 average_score 179.57 epsilon 0.01
# episode:  300 score 200.00 average_score 179.57 epsilon 0.01
# episode:  301 score 200.00 average_score 179.57 epsilon 0.01
# episode:  302 score 157.00 average_score 179.55 epsilon 0.01
# episode:  303 score 128.00 average_score 178.83 epsilon 0.01
# episode:  304 score 168.00 average_score 178.80 epsilon 0.01
# episode:  305 score 200.00 average_score 179.08 epsilon 0.01
# episode:  306 score 136.00 average_score 178.44 epsilon 0.01
# episode:  307 score 200.00 average_score 178.44 epsilon 0.01
# episode:  308 score 200.00 average_score 178.44 epsilon 0.01
# episode:  309 score 200.00 average_score 178.73 epsilon 0.01
# episode:  310 score 172.00 average_score 178.58 epsilon 0.01
# episode:  311 score 200.00 average_score 178.98 epsilon 0.01
# episode:  312 score 145.00 average_score 178.72 epsilon 0.01
# episode:  313 score 175.00 average_score 178.47 epsilon 0.01
# episode:  314 score 13.00 average_score 176.77 epsilon 0.01
# episode:  315 score 8.00 average_score 175.24 epsilon 0.01
# episode:  316 score 10.00 average_score 173.34 epsilon 0.01
# episode:  317 score 10.00 average_score 171.44 epsilon 0.01
# episode:  318 score 10.00 average_score 169.54 epsilon 0.01
# episode:  319 score 10.00 average_score 167.64 epsilon 0.01
# episode:  320 score 8.00 average_score 165.72 epsilon 0.01
# episode:  321 score 10.00 average_score 163.82 epsilon 0.01
# episode:  322 score 9.00 average_score 161.91 epsilon 0.01
# episode:  323 score 10.00 average_score 160.01 epsilon 0.01
# episode:  324 score 11.00 average_score 158.13 epsilon 0.01
# episode:  325 score 9.00 average_score 156.22 epsilon 0.01
# episode:  326 score 10.00 average_score 154.32 epsilon 0.01
# episode:  327 score 10.00 average_score 152.42 epsilon 0.01
# episode:  328 score 10.00 average_score 150.83 epsilon 0.01
# episode:  329 score 11.00 average_score 148.94 epsilon 0.01
# episode:  330 score 9.00 average_score 147.03 epsilon 0.01
# episode:  331 score 9.00 average_score 145.12 epsilon 0.01
# episode:  332 score 9.00 average_score 143.21 epsilon 0.01
# episode:  333 score 9.00 average_score 141.60 epsilon 0.01
# episode:  334 score 10.00 average_score 140.42 epsilon 0.01
# episode:  335 score 8.00 average_score 138.77 epsilon 0.01
# episode:  336 score 9.00 average_score 137.42 epsilon 0.01
# episode:  337 score 10.00 average_score 136.05 epsilon 0.01
# episode:  338 score 9.00 average_score 134.90 epsilon 0.01
# episode:  339 score 98.00 average_score 134.61 epsilon 0.01
# episode:  340 score 22.00 average_score 133.16 epsilon 0.01
# episode:  341 score 23.00 average_score 131.95 epsilon 0.01
# episode:  342 score 27.00 average_score 130.66 epsilon 0.01
# episode:  343 score 10.00 average_score 129.08 epsilon 0.01
# episode:  344 score 11.00 average_score 127.19 epsilon 0.01
# episode:  345 score 12.00 average_score 125.62 epsilon 0.01
# episode:  346 score 14.00 average_score 123.76 epsilon 0.01
# episode:  347 score 15.00 average_score 122.83 epsilon 0.01
# episode:  348 score 14.00 average_score 120.99 epsilon 0.01
# episode:  349 score 12.00 average_score 119.84 epsilon 0.01
# episode:  350 score 9.00 average_score 118.50 epsilon 0.01
# episode:  351 score 14.00 average_score 116.64 epsilon 0.01
# episode:  352 score 14.00 average_score 114.78 epsilon 0.01
# episode:  353 score 14.00 average_score 112.92 epsilon 0.01
# episode:  354 score 18.00 average_score 111.77 epsilon 0.01
# episode:  355 score 13.00 average_score 110.70 epsilon 0.01
# episode:  356 score 13.00 average_score 109.30 epsilon 0.01
# episode:  357 score 14.00 average_score 107.44 epsilon 0.01
# episode:  358 score 13.00 average_score 105.57 epsilon 0.01
# episode:  359 score 14.00 average_score 103.71 epsilon 0.01
# episode:  360 score 16.00 average_score 102.47 epsilon 0.01
# episode:  361 score 13.00 average_score 100.60 epsilon 0.01
# episode:  362 score 19.00 average_score 98.79 epsilon 0.01
# episode:  363 score 26.00 average_score 97.94 epsilon 0.01
# episode:  364 score 15.00 average_score 97.28 epsilon 0.01
# episode:  365 score 16.00 average_score 95.44 epsilon 0.01
# episode:  366 score 19.00 average_score 93.63 epsilon 0.01
# episode:  367 score 12.00 average_score 91.75 epsilon 0.01
# episode:  368 score 15.00 average_score 89.90 epsilon 0.01
# episode:  369 score 14.00 average_score 88.04 epsilon 0.01
# episode:  370 score 13.00 average_score 86.36 epsilon 0.01
# episode:  371 score 16.00 average_score 85.25 epsilon 0.01
# episode:  372 score 23.00 average_score 83.99 epsilon 0.01
# episode:  373 score 19.00 average_score 82.18 epsilon 0.01
# episode:  374 score 19.00 average_score 80.47 epsilon 0.01
# episode:  375 score 27.00 average_score 79.51 epsilon 0.01
# episode:  376 score 26.00 average_score 78.30 epsilon 0.01
# episode:  377 score 34.00 average_score 76.70 epsilon 0.01
# episode:  378 score 56.00 average_score 75.26 epsilon 0.01
# episode:  379 score 73.00 average_score 73.99 epsilon 0.01
# episode:  380 score 72.00 average_score 72.71 epsilon 0.01
# episode:  381 score 99.00 average_score 72.32 epsilon 0.01
# episode:  382 score 89.00 average_score 71.21 epsilon 0.01
# episode:  383 score 105.00 average_score 70.26 epsilon 0.01
# episode:  384 score 130.00 average_score 69.56 epsilon 0.01
# episode:  385 score 131.00 average_score 68.87 epsilon 0.01
# episode:  386 score 156.00 average_score 68.43 epsilon 0.01
# episode:  387 score 180.00 average_score 68.23 epsilon 0.01
# episode:  388 score 200.00 average_score 68.23 epsilon 0.01
# episode:  389 score 200.00 average_score 68.23 epsilon 0.01
# episode:  390 score 199.00 average_score 68.22 epsilon 0.01
# episode:  391 score 200.00 average_score 68.22 epsilon 0.01
# episode:  392 score 200.00 average_score 68.22 epsilon 0.01
# episode:  393 score 200.00 average_score 68.22 epsilon 0.01
# episode:  394 score 200.00 average_score 68.22 epsilon 0.01
# episode:  395 score 200.00 average_score 68.22 epsilon 0.01
# episode:  396 score 200.00 average_score 68.57 epsilon 0.01
# episode:  397 score 200.00 average_score 68.57 epsilon 0.01
# episode:  398 score 200.00 average_score 69.48 epsilon 0.01
# episode:  399 score 200.00 average_score 69.48 epsilon 0.01
# episode:  400 score 200.00 average_score 69.48 epsilon 0.01
# episode:  401 score 200.00 average_score 69.48 epsilon 0.01
# episode:  402 score 200.00 average_score 69.91 epsilon 0.01
# episode:  403 score 200.00 average_score 70.63 epsilon 0.01
# episode:  404 score 200.00 average_score 70.95 epsilon 0.01
# episode:  405 score 200.00 average_score 70.95 epsilon 0.01
# episode:  406 score 200.00 average_score 71.59 epsilon 0.01
# episode:  407 score 200.00 average_score 71.59 epsilon 0.01
# episode:  408 score 200.00 average_score 71.59 epsilon 0.01
# episode:  409 score 200.00 average_score 71.59 epsilon 0.01
# episode:  410 score 200.00 average_score 71.87 epsilon 0.01
# episode:  411 score 200.00 average_score 71.87 epsilon 0.01
# episode:  412 score 200.00 average_score 72.42 epsilon 0.01
# episode:  413 score 200.00 average_score 72.67 epsilon 0.01
# episode:  414 score 190.00 average_score 74.44 epsilon 0.01
# episode:  415 score 200.00 average_score 76.36 epsilon 0.01
# episode:  416 score 200.00 average_score 78.26 epsilon 0.01
# episode:  417 score 200.00 average_score 80.16 epsilon 0.01
# episode:  418 score 200.00 average_score 82.06 epsilon 0.01
# episode:  419 score 200.00 average_score 83.96 epsilon 0.01
# episode:  420 score 200.00 average_score 85.88 epsilon 0.01
# episode:  421 score 200.00 average_score 87.78 epsilon 0.01
# episode:  422 score 200.00 average_score 89.69 epsilon 0.01
# episode:  423 score 200.00 average_score 91.59 epsilon 0.01
# episode:  424 score 115.00 average_score 92.63 epsilon 0.01
# episode:  425 score 79.00 average_score 93.33 epsilon 0.01
# episode:  426 score 74.00 average_score 93.97 epsilon 0.01
# episode:  427 score 115.00 average_score 95.02 epsilon 0.01
# episode:  428 score 126.00 average_score 96.18 epsilon 0.01
# episode:  429 score 200.00 average_score 98.07 epsilon 0.01
# episode:  430 score 200.00 average_score 99.98 epsilon 0.01
# episode:  431 score 155.00 average_score 101.44 epsilon 0.01
# episode:  432 score 200.00 average_score 103.35 epsilon 0.01
# episode:  433 score 200.00 average_score 105.26 epsilon 0.01
# episode:  434 score 200.00 average_score 107.16 epsilon 0.01
# episode:  435 score 200.00 average_score 109.08 epsilon 0.01
# episode:  436 score 200.00 average_score 110.99 epsilon 0.01
# episode:  437 score 200.00 average_score 112.89 epsilon 0.01
# episode:  438 score 200.00 average_score 114.80 epsilon 0.01
# episode:  439 score 200.00 average_score 115.82 epsilon 0.01
# episode:  440 score 200.00 average_score 117.60 epsilon 0.01
# episode:  441 score 200.00 average_score 119.37 epsilon 0.01
# episode:  442 score 200.00 average_score 121.10 epsilon 0.01
# episode:  443 score 112.00 average_score 122.12 epsilon 0.01
# episode:  444 score 200.00 average_score 124.01 epsilon 0.01
# episode:  445 score 200.00 average_score 125.89 epsilon 0.01
# episode:  446 score 200.00 average_score 127.75 epsilon 0.01
# episode:  447 score 200.00 average_score 129.60 epsilon 0.01
# episode:  448 score 200.00 average_score 131.46 epsilon 0.01
# episode:  449 score 200.00 average_score 133.34 epsilon 0.01
# episode:  450 score 200.00 average_score 135.25 epsilon 0.01
# episode:  451 score 200.00 average_score 137.11 epsilon 0.01
# episode:  452 score 200.00 average_score 138.97 epsilon 0.01
# episode:  453 score 180.00 average_score 140.63 epsilon 0.01
# episode:  454 score 200.00 average_score 142.45 epsilon 0.01
# episode:  455 score 200.00 average_score 144.32 epsilon 0.01
# episode:  456 score 148.00 average_score 145.67 epsilon 0.01
# episode:  457 score 144.00 average_score 146.97 epsilon 0.01
# episode:  458 score 200.00 average_score 148.84 epsilon 0.01
# episode:  459 score 200.00 average_score 150.70 epsilon 0.01
# episode:  460 score 200.00 average_score 152.54 epsilon 0.01
# episode:  461 score 173.00 average_score 154.14 epsilon 0.01
# episode:  462 score 110.00 average_score 155.05 epsilon 0.01
# episode:  463 score 95.00 average_score 155.74 epsilon 0.01
# episode:  464 score 79.00 average_score 156.38 epsilon 0.01
# episode:  465 score 100.00 average_score 157.22 epsilon 0.01
# episode:  466 score 130.00 average_score 158.33 epsilon 0.01
# episode:  467 score 200.00 average_score 160.21 epsilon 0.01
# episode:  468 score 200.00 average_score 162.06 epsilon 0.01
# episode:  469 score 93.00 average_score 162.85 epsilon 0.01
# episode:  470 score 135.00 average_score 164.07 epsilon 0.01
# episode:  471 score 200.00 average_score 165.91 epsilon 0.01
# episode:  472 score 200.00 average_score 167.68 epsilon 0.01
# episode:  473 score 186.00 average_score 169.35 epsilon 0.01
# episode:  474 score 200.00 average_score 171.16 epsilon 0.01
# episode:  475 score 200.00 average_score 172.89 epsilon 0.01
# episode:  476 score 200.00 average_score 174.63 epsilon 0.01
# episode:  477 score 200.00 average_score 176.29 epsilon 0.01
# episode:  478 score 200.00 average_score 177.73 epsilon 0.01
# episode:  479 score 190.00 average_score 178.90 epsilon 0.01
# episode:  480 score 200.00 average_score 180.18 epsilon 0.01
# episode:  481 score 200.00 average_score 181.19 epsilon 0.01
# episode:  482 score 200.00 average_score 182.30 epsilon 0.01
# episode:  483 score 200.00 average_score 183.25 epsilon 0.01
# episode:  484 score 200.00 average_score 183.95 epsilon 0.01
# episode:  485 score 121.00 average_score 183.85 epsilon 0.01
# episode:  486 score 200.00 average_score 184.29 epsilon 0.01
# episode:  487 score 200.00 average_score 184.49 epsilon 0.01
# episode:  488 score 119.00 average_score 183.68 epsilon 0.01
# episode:  489 score 200.00 average_score 183.68 epsilon 0.01
# episode:  490 score 171.00 average_score 183.40 epsilon 0.01
# episode:  491 score 200.00 average_score 183.40 epsilon 0.01
# episode:  492 score 200.00 average_score 183.40 epsilon 0.01
# episode:  493 score 200.00 average_score 183.40 epsilon 0.01
# episode:  494 score 132.00 average_score 182.72 epsilon 0.01
# episode:  495 score 172.00 average_score 182.44 epsilon 0.01
# episode:  496 score 200.00 average_score 182.44 epsilon 0.01
# episode:  497 score 147.00 average_score 181.91 epsilon 0.01
# episode:  498 score 115.00 average_score 181.06 epsilon 0.01
# episode:  499 score 130.00 average_score 180.36 epsilon 0.01
